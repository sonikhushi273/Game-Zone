# %%
d = {'admin':'Qwert@123'}
dsq = {'admin':'petname'}
quesList = ['Which is your favourite pet?',
         'What is your childhood name?']

# %%
def checkPasswordStrength(password):
    uc = lc = sc = ac = dc = 0
    strength = 0
    spec = '!@#$%^&*()_+<>?'
    
    for char in password:
        if char.isalpha():         
            ac += 1
            if char.isupper():     uc += 1
            elif char.islower():   lc += 1
        elif char.isdigit():       dc += 1        
        elif char in spec:         sc += 1
    
    if len(password)>8:            strength += 1
    if ac >= 1 and dc >= 1:        strength += 1
    if uc >= 1 and lc >= 1:        strength += 1
    if sc >= 1:                    strength += 1

    if strength >= 3:              return True
    else:                          return False
    
    
#checkPasswordStrength("Qwerty@123")

# %%
def forgotPassword(username):
    flag = 3
    while flag:
        q=input('''press 1 for security question or
press 2 for verification by otp
                       ''')
        if q=='1':
            securityQuestions("Admin")
        elif q=='2':
            otps()
            z=input("enter otp: ")
            if z==otps:
                print("Valid OTP") 
                
            else:
                print("invalide otps")
                flag -= 1
            
        else:
            print("enter valid input")
            flag -= 1

# forgotPassword("Admin")

# %%
def otps():
    import os
    from twilio.rest import Client
    account_sid = "AC84d036734e1befe327e89557348044b6"
    auth_token = "762459187bcbc48aa4bff5a9f70c72f6"
    verify_sid = "VAb5e1382c394da4b15e18e27ee98981b3"
    verified_number = "+919770393928"

    client = Client(account_sid, auth_token)

    verification = client.verify.v2.services(verify_sid) \
    .verifications \
    .create(to=verified_number, channel="sms")
    print(verification.status)

    otp_code = input("Please enter the OTP:")

    verification_check = client.verify.v2.services(verify_sid) \
    .verification_checks \
    .create(to=verified_number, code=otp_code)
    print(verification_check.status)
#otps()

# %%
def securityQuestions(username):
    print("\n****Please answer the security questions****")
    while True:
        ans1 = input(quesList[0]).lower()
        ans2 = input(quesList[1]).lower()
        sta = input('Are the answers final? Y/N: ').lower()
        if sta == 'y':
            dsq[username] = [ans1, ans2]
            print('Security Questions Saved...')
            return
    
# securityQuestions("Admin")

# %%
def signUp():
    print("\n****Welcome to Coding Thinker SignUp Page****")
    while 1:
        userUp = input('Enter a new Username: ').lower()
        if userUp == '0':
            return 'Failed'
        elif userUp not in d:
            print("""# Length > 8
    # Upper case + Lower Case
    # Special Characters
    # Alphabets and Digits""")
            while(1):
                passUp = input('Enter a strong password: ')
                if passUp == "0":
                    return 'Failed'
                elif checkPasswordStrength(passUp):
                    d.update({userUp:passUp})       # d[userUp] = passUp
                    securityQuestions(userUp)
                    return 'Successful'
                else:
                    print('''Password is weak... Try stronger Password
                    Press 0 to Exit
                    or ''') 
        else:
            print('''Username already exists. Please try another...
                  Press 0 to exit
                  or ''')
#signUp()

# %%
def rps(userName1):    
    print("Welcome to Rock, paper, scissors, shoot! Game...")
    userName1 = input("Enter a First name: ").title()
    userName2 =  input("Enter a First name: ").title()
    count1 = count2 = 0
    choices = ['rock', 'paper', 'scissors']
    while True:
        user1 = input(f"{userName1} Enter your choice: ").lower()
        user2 = input(f"{userName2} Enter your choice: ").lower()
        print(userName2,"chooses", user2)

        if (user1 == 'rock') and (user2 == 'paper'):
            print(userName2, "Wins")
            count2 += 1
        elif (user1 == 'rock') and (user2 == 'scissors'):
            print(userName1, "Wins")
            count1 += 1 
        elif (user1 == 'paper') and (user2 == 'rock'):
            print(userName1, "Wins")
            count1 += 1
        elif (user1 == 'paper') and (user2 == 'scissors'):
            print(userName2, "Wins")
            count2 += 1
        elif (user1 == 'scissors') and (user2 == 'paper'):
            print(userName1, "Wins")
            count1 += 1
        elif (user1 == 'scissors') and (user2 == 'rock'):
            print(userName2, "Wins")
            count2 += 1
        elif user1 == user2:
            print("Tie")
        else:
            print("Invalid choice!")
            
        con = input('Do you want to continue? Y/N:  ').lower()
        if con != 'y':
            break

    if count1 > count2:
        print('Final Winner is', userName1)
    elif count1 < count2:
        print('Final Winner is', userName2)
    else:
        print('Game Draw')
    return

#rps('Admin')

# %%
import random

questions = [
    {
        'question': 'What is the capital city of India?',
        'options': ['A. Lucknow', 'B. Delhi', 'C. Pune', 'D. Agra'],
        'answer': 'B'
    },
    {
        'question': 'Who discovered India?',
        'options': ['A. Vasco da Gama', 'B. Antonio de Abreu', 'C. Thomas Wyndham', 'D. Sir Richard Guildford'],
        'answer': 'A'
    },
    {
        'question': 'Where is the Taj Mahal located?',
        'options': ['A. Delhi', 'B. Agra', 'C. Mumbai', 'D. Jaipur'],
        'answer': 'B'
    },
    {
        'question': 'Which city is called the Pink City?',
        'options': ['A. Udaipur', 'B. Jodhpur', 'C. Jaipur', 'D. Delhi'],
        'answer': 'C'
    },
    {
        'question': 'Which state capital is Gandhinagar?',
        'options': ['A. Maharashtra', 'B. Uttar Pradesh', 'C. Assam', 'D. Gujarat'],
        'answer': 'D'
    },
    {
        'question': 'There are how many continents in the world?',
        'options': ['A. 5', 'B. 6', 'C. 8', 'D. 7'],
        'answer': 'D'
    },
    {
        'question': 'What is the capital of Maharashtra?',
        'options': ['A. Nagpur', 'B. Pune', 'C. Mumbai', 'D. None of the above'],
        'answer': 'C'
    },
    {
        'question': 'Which festival is known as the Festival of Lights in India?',
        'options': ['A. Holi', 'B. Diwali', 'C. Dussehra', 'D. Eid'],
        'answer': 'B'
    },
    {
        'question': 'What is the name of the holiday commemorating Jesus Christs resurrection after his crucifixion?',
        'options': ['A. Good Friday', 'B. Easter', 'C. Christmas', 'D. None of the above'],
        'answer': 'B'
    },
    {
        'question': 'Who is popularly known as the Iron Man of India?',
        'options': ['A. Jawaharlal Nehru', 'B. Mahatma Gandhi', 'C. Sardar Vallabhai Patel', 'D. Bhagat Singh'],
        'answer': 'C'
    }
]

rewards = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]

def kbc(UserName1):
    print("Welcome to Kaun Banega Crorepati!!!!!!!!!!!")
    random.shuffle(questions)
    lifelines = ["50-50", "Audience Poll", "Double Dip"]
    total_questions = len(questions)
    total_reward = 0
    correct_answers = 0

    for i in range(total_questions):
        current_question = questions[i]
        options = current_question["options"]
        print(f"Question {i + 1}: {current_question['question']}")
        for option in options:
            print(option)
        answer = current_question["answer"]
        reward = rewards[i]

        while True:
            choice = input("Enter your answer (A/B/C/D) or lifeline (50-50/Audience Poll/Double Dip) OR 'QUIT' to quit:\n").upper()
            if choice == answer:
                print("Correct answer!")
                correct_answers += 1
                total_reward += reward
                print(f"You have won Rs. {reward}")
                break
            elif choice == "50-50":
                print("Using 50-50 lifeline...")
                random_options = random.sample(options, 2)
                random_options.append(answer)
                random.shuffle(random_options)
                print(f"The options now are: {random_options[0]} and {random_options[1]}")
            elif choice == "AUDIENCE POLL":
                print("Using Audience Poll lifeline...")
                print("The audience poll results are as follows:")
                for option in options:
                    if option == answer:
                        percentage = random.randint(60, 95)
                    else:
                        percentage = random.randint(5, 30)
                    print(f"{option}: {percentage}%")
            elif choice == "DOUBLE DIP":
                print("Using Double Dip lifeline.......")
                print("Select two options")
                trial1 = input("Enter your first choice: ").upper()
                if answer == trial1:
                    print("Correct Answer, well done....")
                    break
                else:
                    print("Your first trial is wrong, choose another")
                    trial2 = input("Enter your second choice: ").upper()
                    if answer == trial2:
                        print("Correct Answer")
                    else:
                        print("Your second trial is also wrong..Better luck next time..")
                        print("Correct Answer is:", answer)
                    break
            elif choice == "QUIT":
                print("You quit the game.")
                return
            else:
                print("Invalid choice. Please enter a valid answer or lifeline.")

    print("Game Over!")
    print(f"You answered {correct_answers} questions correctly.")
    print(f"Total reward: Rs. {total_reward}")


# kbc("Admin")

# %%
def gaming(userName):
    while True:
        gameChoice = input('''Which game do you want to play?
        Press 1 for Rock,Paper,Scissor
        Press 2 for KBC
        Press 0 to Exit
        : ''')
        if gameChoice == '1':
            rps(userName)
        elif gameChoice == '2':
            kbc(userName)
            pass
        elif gameChoice == '0':
            print('We are sorry to see you go...')
            return
        else:
            print('Invalid Choice')
            
#gaming('Admin')

# %%
def signIn():
    print("\n****Welcome to Coding Thinker SignIn Page****")
    while 1:
        userIn = input("Enter your existing Username: ").lower()
        if userIn == "0":
            return 'Failed'
        if userIn == '1':
            if signUp(username) == 'Successful':
                continue
            else:
                return 'Failed'
        if userIn in d:
            flag = 3       # status flag
            while flag:
                passIn = input('Enter your Password: ')
                if d[userIn] == passIn:
                    # loginMenu(userIn)
                    return 'Successful'
                else:
                    print('Password Incorrect. Please try again...')
                    fp = input('Forgot Password? Y/N: ').lower()
                    if fp == 'y':
                        forgotPassword("Admin")
                        print('Password Reset...')
                        break
                    else:
                        flag -= 1
        
            if flag == 0: return 'Failed'
        else:
            print("""Username doesn't exist. Please try again...
            Press 0 to Exit
            Press 1 to SignUp with a new Username
            or """)
#signIn()

# %%
while True:
    mode = input("""
    Press 1 for SignUp
    Press 2 for SignIn
    Press 0 to Exit
                     : """)
    if mode == '1':
        print('SignUp', signUp())
        
    elif mode == '2':
        print('SignIn', signIn())
        gaming('Admin')
        
    elif mode == '0':
        print('Thanks!')
        break
    
    else:
        print('Invalid input. Please try again...')
# Out:
# ****Welcome to Coding Thinker SignUp Page****
# # Length > 8
#     # Upper case + Lower Case
#     # Special Characters
#     # Alphabets and Digits
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
#
# ****Please answer the security questions****
# Security Questions Saved...
# SignUp Successful
#
# ****Welcome to Coding Thinker SignUp Page****
# # Length > 8
#     # Upper case + Lower Case
#     # Special Characters
#     # Alphabets and Digits
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# Password is weak... Try stronger Password
#                     Press 0 to Exit
#                     or
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\sonik\Documents\Khushi_Projects\Game Zone.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> mode = input("""
#       <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> Press 1 for SignUp
#       <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> Press 2 for SignIn
#       <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> Press 0 to Exit
#       <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a>                  : """)
#       <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> if mode == '1':
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a>     print('SignUp', signUp())
#      <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a> elif mode == '2':
#      <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a>     print('SignIn', signIn())
#
# c:\Users\sonik\Documents\Khushi_Projects\Game Zone.ipynb Cell 11 in signUp()
#       <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a>         print("""# Length > 8
#       <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a> # Upper case + Lower Case
#      <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a> # Special Characters
#      <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> # Alphabets and Digits""")
#      <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a>         while(1):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a>             passUp = input('Enter a strong password: ')
#      <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a>             if passUp == "0":
#      <a href='vscode-notebook-cell:/c%3A/Users/sonik/Documents/Khushi_Projects/Game%20Zone.ipynb#X13sZmlsZQ%3D%3D?line=14'>15</a>                 return 'Failed'
#
# File c:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# File c:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py:1120, in Kernel._input_request(self, prompt, ident, parent, password)
#    1117             break
#    1118 except KeyboardInterrupt:
#    1119     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1120     raise KeyboardInterrupt("Interrupted by user") from None
#    1121 except Exception:
#    1122     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
